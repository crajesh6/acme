# %%
import glob, h5py, os, re, sys, time
from pathlib import Path
from filelock import FileLock

import numpy as np
import pandas as pd
from multiprocess import Pool
from tqdm.notebook import tqdm
from six.moves import cPickle
import sh
from tqdm import tqdm

from acme.kmer import kmer_featurization
from acme import interval
from acme import utils
# Out:
# 2022-10-07 08:37:29.735676: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
BASE_DIR = Path.cwd().parent
DATA_DIR = BASE_DIR.joinpath("data/atac/cell_line_testsets")
evaluation_path = BASE_DIR.joinpath("data/atac/atac_model_pearson.csv")
saliency_dir = BASE_DIR.joinpath("data/atac/saliency_repo")
saliency_subset_dir = BASE_DIR.joinpath("data/atac/saliency_subset")

# cell line paths
cell_line_dict = {
    "A549": f"{DATA_DIR}/cell_line_8.h5",
    "HCT116": f"{DATA_DIR}/cell_line_9.h5",
    "GM12878": f"{DATA_DIR}/cell_line_7.h5",
    "K562": f"{DATA_DIR}/cell_line_5.h5",
    "PC-3": f"{DATA_DIR}/cell_line_13.h5",
    "HepG2": f"{DATA_DIR}/cell_line_2.h5"
}

model_dict = {
    "new_models_Residual_32_task_Exp": "residual_32_task_exp",
    "new_models_CNN_1_all_Exp": "cnn_base_all_exp",
    "new_models_Residual_32_all_Exp": "residual_32_all_exp",
    "new_models_CNN_32_all_Exp": "cnn_32_all_exp",
    "new_models_Residual_32_task_ReLU": "residual_32_task_relu",
    "binary_basenji_binary_exp": "binary_basenji_exp",
    "bpnet_augmentation_48": "bpnet",
    "binary_residual_binary": "binary_residual_relu",
    "new_models_Residual_1_task_Exp": "residual_base_task_exp",
    "binary_basenji_binary": "binary_basenji_relu",
    "new_models_CNN_32_task_Exp": "cnn_32_task_exp",
    "new_models_Residual_1_all_Exp": "residual_base_all_exp",
    "binary_residual_binary_exp": "binary_residual_exp",
    "new_models_CNN_1_task_ReLU": "cnn_base_task_relu",
    "binary_conv_binary_exp": "binary_cnn_exp",
    "binary_basset_exp": "binary_basset_exp",
    "new_models_Residual_1_all_ReLU": "residual_base_all_relu",
    "binary_basset": "binary_basset_relu",
    "new_models_CNN_32_task_ReLU": "cnn_32_task_relu",
    "new_models_CNN_32_all_ReLU": "cnn_32_all_relu",
    "new_models_CNN_1_task_Exp": "cnn_base_task_exp",
    "new_models_Residual_1_task_ReLU": "residual_base_task_relu",
    "basenji_v2_binloss_basenji_v2": "basenji_v2_binloss_relu",
    "new_models_Residual_32_all_ReLU": "residual_32_all_relu",
    "new_models_CNN_1_all_ReLU": "cnn_base_all_relu",
    "binary_conv_binary": "binary_cnn_relu"
}

print(BASE_DIR, evaluation_path, DATA_DIR, saliency_dir)
# Out:
# /shared/data00/acme /shared/data00/acme/data/atac/atac_model_pearson.csv /shared/data00/acme/data/atac/cell_line_testsets /shared/data00/acme/data/atac/saliency_repo

# %%
# df = utils.make_directories_atac(out_dir=out_dir, source_paths=saliency_dir)

# %%
df = utils.get_model_info(saliency_dir=saliency_subset_dir)

# %%
df
# Out:
#                       model cell_line  \
# 0        binary_basset_relu   GM12878
# 1      binary_residual_relu   GM12878
# 2           binary_cnn_relu   GM12878
# 3       binary_basenji_relu   GM12878
# 4            binary_cnn_exp   GM12878
# 5        binary_basenji_exp   GM12878
# 6         binary_basset_exp   GM12878
# 7       binary_residual_exp   GM12878
# 8           cnn_32_all_relu   GM12878
# 9          cnn_32_task_relu   GM12878
# 10        cnn_base_all_relu   GM12878
# 11                    bpnet   GM12878
# 12       cnn_base_task_relu   GM12878
# 13   residual_base_all_relu   GM12878
# 14     residual_32_all_relu   GM12878
# 15  residual_base_task_relu   GM12878
# 16  basenji_v2_binloss_relu   GM12878
# 17    residual_32_task_relu   GM12878
# 18    residual_base_all_exp   GM12878
# 19        cnn_base_task_exp   GM12878
# 20          cnn_32_task_exp   GM12878
# 21     residual_32_task_exp   GM12878
# 22           cnn_32_all_exp   GM12878
# 23      residual_32_all_exp   GM12878
# 24         cnn_base_all_exp   GM12878
# 25   residual_base_task_exp   GM12878
#
#                                         cell_line_dir  \
# 0   /shared/data00/acme/data/atac/cell_line_testse...
# 1   /shared/data00/acme/data/atac/cell_line_testse...
# 2   /shared/data00/acme/data/atac/cell_line_testse...
# 3   /shared/data00/acme/data/atac/cell_line_testse...
# 4   /shared/data00/acme/data/atac/cell_line_testse...
# 5   /shared/data00/acme/data/atac/cell_line_testse...
# 6   /shared/data00/acme/data/atac/cell_line_testse...
# 7   /shared/data00/acme/data/atac/cell_line_testse...
# 8   /shared/data00/acme/data/atac/cell_line_testse...
# 9   /shared/data00/acme/data/atac/cell_line_testse...
# 10  /shared/data00/acme/data/atac/cell_line_testse...
# 11  /shared/data00/acme/data/atac/cell_line_testse...
# 12  /shared/data00/acme/data/atac/cell_line_testse...
# 13  /shared/data00/acme/data/atac/cell_line_testse...
# 14  /shared/data00/acme/data/atac/cell_line_testse...
# 15  /shared/data00/acme/data/atac/cell_line_testse...
# 16  /shared/data00/acme/data/atac/cell_line_testse...
# 17  /shared/data00/acme/data/atac/cell_line_testse...
# 18  /shared/data00/acme/data/atac/cell_line_testse...
# 19  /shared/data00/acme/data/atac/cell_line_testse...
# 20  /shared/data00/acme/data/atac/cell_line_testse...
# 21  /shared/data00/acme/data/atac/cell_line_testse...
# 22  /shared/data00/acme/data/atac/cell_line_testse...
# 23  /shared/data00/acme/data/atac/cell_line_testse...
# 24  /shared/data00/acme/data/atac/cell_line_testse...
# 25  /shared/data00/acme/data/atac/cell_line_testse...
#
#                                         attr_map_path     task_type activation
# 0   /shared/data00/acme/data/atac/saliency_subset/...        binary       relu
# 1   /shared/data00/acme/data/atac/saliency_subset/...        binary       relu
# 2   /shared/data00/acme/data/atac/saliency_subset/...        binary       relu
# 3   /shared/data00/acme/data/atac/saliency_subset/...        binary       relu
# 4   /shared/data00/acme/data/atac/saliency_subset/...        binary        exp
# 5   /shared/data00/acme/data/atac/saliency_subset/...        binary        exp
# 6   /shared/data00/acme/data/atac/saliency_subset/...        binary        exp
# 7   /shared/data00/acme/data/atac/saliency_subset/...        binary        exp
# 8   /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 9   /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 10  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 11  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 12  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 13  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 14  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 15  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 16  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 17  /shared/data00/acme/data/atac/saliency_subset/...  quantitative       relu
# 18  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 19  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 20  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 21  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 22  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 23  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 24  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp
# 25  /shared/data00/acme/data/atac/saliency_subset/...  quantitative        exp

# %%
out_dir = BASE_DIR.joinpath("data/atac/saliency_subset")

cell_subset = ["GM12878"]


for i in range(len(df)):


    model = df.iloc[i]['model']
    model = model_dict[model]
    attr_map_path = df.iloc[i]['attr_map_path']
    cell_line_dir = cell_line_dict[df.iloc[i]['cell_line']]
    cell_line = df.iloc[i]['cell_line']

    task_type = df.iloc[i]['task_type']
    activation = df.iloc[i]['activation']


    if(cell_line in cell_subset):

            out_path = f"{out_dir}/{cell_line}/{task_type}/{activation}" #/{model}"
            Path(f"{out_path}").mkdir(parents=True, exist_ok=True)

            # copy the files to the subset path
#             sh.cp(attr_map_path, f"{out_path}/{model}.pickle")

# %% [markdown]
# # Evaluate consistency

# %%
cell_subset = ["GM12878"]


for i in tqdm(range(len(df))):


    model = df.iloc[i]['model']
    model = model_dict[model]
    attr_map_path = df.iloc[i]['attr_map_path']
    cell_line_dir = cell_line_dict[df.iloc[i]['cell_line']]
    cell_line = df.iloc[i]['cell_line']

    task_type = df.iloc[i]['task_type']
    activation = df.iloc[i]['activation']


    if(cell_line in cell_subset):

            new_path = f"{out_dir}/{cell_line}/{task_type}/{activation}/{model}.pickle"
            
            a1, _, _ = utils.load_data(attr_map_path=attr_map_path, cell_line_dir=cell_line_dir)
            a2, _, _ = utils.load_data(attr_map_path=new_path, cell_line_dir=cell_line_dir)
            
            if not (np.array_equal(a1, a2)):
                print(f"Not equal for model: {attr_map_path}")
# Out:
#  54%|█████████████████████████████████████████████████████████████▉                                                     | 84/156 [00:19<00:25,  2.82it/s]/home/chandana/projects/acme/acme/utils.py:57: RuntimeWarning: invalid value encountered in true_divide
#   attr_map = attr_map / np.sqrt(np.sum(np.sum(np.square(attr_map), axis=-1, keepdims=True), axis=-2, keepdims=True))
#  60%|█████████████████████████████████████████████████████████████████████▎                                             | 94/156 [00:20<00:14,  4.31it/s]
# Not equal for model: /shared/data00/chandana/acme/data/atac/saliency_repo/binary_basset_exp_GM12878.pickle
#  66%|███████████████████████████████████████████████████████████████████████████▎                                      | 103/156 [00:23<00:14,  3.71it/s]
# Not equal for model: /shared/data00/chandana/acme/data/atac/saliency_repo/binary_basset_GM12878.pickle
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 156/156 [00:33<00:00,  4.64it/s]

# %%
# This is because these models contain NaNs!

# %% [markdown]
# # Rename models in the evaluation results

# %%
df = pd.read_csv("/shared/data00/acme/data/atac/atac_model_pearson.csv")
df
# Out:
#     Unnamed: 0                        model_name      A549    HCT116  \
# 0            0         binary_basenji_binary_exp  0.631905  0.634136
# 1            1                     binary_basset  0.644551  0.623511
# 2            2                binary_conv_binary  0.648810  0.622500
# 3            3                 binary_basset_exp  0.631002  0.620310
# 4            4        binary_residual_binary_exp  0.639870  0.645721
# 5            5            binary_residual_binary  0.638054  0.651104
# 6            6             binary_basenji_binary  0.592449  0.592355
# 7            7            binary_conv_binary_exp  0.641775  0.643460
# 8            8    new_models_Residual_1_task_Exp  0.754242  0.719093
# 9            9   new_models_Residual_1_task_ReLU  0.735452  0.704582
# 10          10     new_models_Residual_1_all_Exp  0.757970  0.719471
# 11          11    new_models_Residual_1_all_ReLU  0.745465  0.713624
# 12          12   new_models_Residual_32_task_Exp  0.749078  0.721714
# 13          13  new_models_Residual_32_task_ReLU  0.738883  0.710612
# 14          14    new_models_Residual_32_all_Exp  0.732858  0.704847
# 15          15   new_models_Residual_32_all_ReLU  0.720982  0.695657
# 16          16         new_models_CNN_1_task_Exp  0.717903  0.673234
# 17          17        new_models_CNN_1_task_ReLU  0.731765  0.694181
# 18          18          new_models_CNN_1_all_Exp  0.728898  0.685016
# 19          19         new_models_CNN_1_all_ReLU  0.730026  0.682136
# 20          20        new_models_CNN_32_task_Exp  0.720688  0.676133
# 21          21       new_models_CNN_32_task_ReLU  0.726958  0.683580
# 22          22         new_models_CNN_32_all_Exp  0.721079  0.672452
# 23          23        new_models_CNN_32_all_ReLU  0.728933  0.685992
# 24          24     basenji_v2_binloss_basenji_v2  0.740202  0.699162
# 25          25             bpnet_augmentation_48  0.737374  0.710005
#
#      GM12878      K562      PC-3     HepG2
# 0   0.556909  0.610139  0.498113  0.612955
# 1   0.540928  0.592135  0.492168  0.586155
# 2   0.521219  0.605254  0.505533  0.598627
# 3   0.514730  0.598176  0.500083  0.569723
# 4   0.606411  0.606989  0.578999  0.635519
# 5   0.606609  0.612077  0.578736  0.645325
# 6   0.496773  0.514070  0.450311  0.550426
# 7   0.580139  0.607368  0.552579  0.621994
# 8   0.669570  0.687969  0.584345  0.673214
# 9   0.645654  0.683041  0.538408  0.667204
# 10  0.667432  0.686772  0.600329  0.679293
# 11  0.652030  0.683239  0.561896  0.669989
# 12  0.685792  0.689395  0.617952  0.729218
# 13  0.661004  0.691644  0.586359  0.715892
# 14  0.662590  0.673304  0.589967  0.704706
# 15  0.644368  0.672157  0.562369  0.688994
# 16  0.598886  0.671332  0.489284  0.655765
# 17  0.613117  0.673166  0.529403  0.658106
# 18  0.604632  0.669928  0.494843  0.658521
# 19  0.584849  0.667611  0.508629  0.652250
# 20  0.598934  0.669961  0.489532  0.656299
# 21  0.589879  0.673263  0.513438  0.656201
# 22  0.596403  0.668972  0.494632  0.656075
# 23  0.595297  0.668940  0.515846  0.654260
# 24  0.652223  0.681122  0.579475  0.711553
# 25  0.640610  0.675683  0.556392  0.667583

# %%
new_model_names = [model_dict[i] for i in df["model_name"]]

# %%
df.insert(1, "new_model_name", new_model_names)
df
# Out:
#     Unnamed: 0           new_model_name                        model_name  \
# 0            0       binary_basenji_exp         binary_basenji_binary_exp
# 1            1       binary_basset_relu                     binary_basset
# 2            2          binary_cnn_relu                binary_conv_binary
# 3            3        binary_basset_exp                 binary_basset_exp
# 4            4      binary_residual_exp        binary_residual_binary_exp
# 5            5     binary_residual_relu            binary_residual_binary
# 6            6      binary_basenji_relu             binary_basenji_binary
# 7            7           binary_cnn_exp            binary_conv_binary_exp
# 8            8   residual_base_task_exp    new_models_Residual_1_task_Exp
# 9            9  residual_base_task_relu   new_models_Residual_1_task_ReLU
# 10          10    residual_base_all_exp     new_models_Residual_1_all_Exp
# 11          11   residual_base_all_relu    new_models_Residual_1_all_ReLU
# 12          12     residual_32_task_exp   new_models_Residual_32_task_Exp
# 13          13    residual_32_task_relu  new_models_Residual_32_task_ReLU
# 14          14      residual_32_all_exp    new_models_Residual_32_all_Exp
# 15          15     residual_32_all_relu   new_models_Residual_32_all_ReLU
# 16          16        cnn_base_task_exp         new_models_CNN_1_task_Exp
# 17          17       cnn_base_task_relu        new_models_CNN_1_task_ReLU
# 18          18         cnn_base_all_exp          new_models_CNN_1_all_Exp
# 19          19        cnn_base_all_relu         new_models_CNN_1_all_ReLU
# 20          20          cnn_32_task_exp        new_models_CNN_32_task_Exp
# 21          21         cnn_32_task_relu       new_models_CNN_32_task_ReLU
# 22          22           cnn_32_all_exp         new_models_CNN_32_all_Exp
# 23          23          cnn_32_all_relu        new_models_CNN_32_all_ReLU
# 24          24  basenji_v2_binloss_relu     basenji_v2_binloss_basenji_v2
# 25          25                    bpnet             bpnet_augmentation_48
#
#         A549    HCT116   GM12878      K562      PC-3     HepG2
# 0   0.631905  0.634136  0.556909  0.610139  0.498113  0.612955
# 1   0.644551  0.623511  0.540928  0.592135  0.492168  0.586155
# 2   0.648810  0.622500  0.521219  0.605254  0.505533  0.598627
# 3   0.631002  0.620310  0.514730  0.598176  0.500083  0.569723
# 4   0.639870  0.645721  0.606411  0.606989  0.578999  0.635519
# 5   0.638054  0.651104  0.606609  0.612077  0.578736  0.645325
# 6   0.592449  0.592355  0.496773  0.514070  0.450311  0.550426
# 7   0.641775  0.643460  0.580139  0.607368  0.552579  0.621994
# 8   0.754242  0.719093  0.669570  0.687969  0.584345  0.673214
# 9   0.735452  0.704582  0.645654  0.683041  0.538408  0.667204
# 10  0.757970  0.719471  0.667432  0.686772  0.600329  0.679293
# 11  0.745465  0.713624  0.652030  0.683239  0.561896  0.669989
# 12  0.749078  0.721714  0.685792  0.689395  0.617952  0.729218
# 13  0.738883  0.710612  0.661004  0.691644  0.586359  0.715892
# 14  0.732858  0.704847  0.662590  0.673304  0.589967  0.704706
# 15  0.720982  0.695657  0.644368  0.672157  0.562369  0.688994
# 16  0.717903  0.673234  0.598886  0.671332  0.489284  0.655765
# 17  0.731765  0.694181  0.613117  0.673166  0.529403  0.658106
# 18  0.728898  0.685016  0.604632  0.669928  0.494843  0.658521
# 19  0.730026  0.682136  0.584849  0.667611  0.508629  0.652250
# 20  0.720688  0.676133  0.598934  0.669961  0.489532  0.656299
# 21  0.726958  0.683580  0.589879  0.673263  0.513438  0.656201
# 22  0.721079  0.672452  0.596403  0.668972  0.494632  0.656075
# 23  0.728933  0.685992  0.595297  0.668940  0.515846  0.654260
# 24  0.740202  0.699162  0.652223  0.681122  0.579475  0.711553
# 25  0.737374  0.710005  0.640610  0.675683  0.556392  0.667583

# %%
# Save to csv
# df.to_csv("/shared/data00/acme/data/atac/atac_model_pearson_copy.csv", index=None)

# %%
# double check for accuracy
pd.read_csv("/shared/data00/acme/data/atac/atac_model_pearson_copy.csv")
# Out:
#     Unnamed: 0           new_model_name                        model_name  \
# 0            0       binary_basenji_exp         binary_basenji_binary_exp
# 1            1       binary_basset_relu                     binary_basset
# 2            2          binary_cnn_relu                binary_conv_binary
# 3            3        binary_basset_exp                 binary_basset_exp
# 4            4      binary_residual_exp        binary_residual_binary_exp
# 5            5     binary_residual_relu            binary_residual_binary
# 6            6      binary_basenji_relu             binary_basenji_binary
# 7            7           binary_cnn_exp            binary_conv_binary_exp
# 8            8   residual_base_task_exp    new_models_Residual_1_task_Exp
# 9            9  residual_base_task_relu   new_models_Residual_1_task_ReLU
# 10          10    residual_base_all_exp     new_models_Residual_1_all_Exp
# 11          11   residual_base_all_relu    new_models_Residual_1_all_ReLU
# 12          12     residual_32_task_exp   new_models_Residual_32_task_Exp
# 13          13    residual_32_task_relu  new_models_Residual_32_task_ReLU
# 14          14      residual_32_all_exp    new_models_Residual_32_all_Exp
# 15          15     residual_32_all_relu   new_models_Residual_32_all_ReLU
# 16          16        cnn_base_task_exp         new_models_CNN_1_task_Exp
# 17          17       cnn_base_task_relu        new_models_CNN_1_task_ReLU
# 18          18         cnn_base_all_exp          new_models_CNN_1_all_Exp
# 19          19        cnn_base_all_relu         new_models_CNN_1_all_ReLU
# 20          20          cnn_32_task_exp        new_models_CNN_32_task_Exp
# 21          21         cnn_32_task_relu       new_models_CNN_32_task_ReLU
# 22          22           cnn_32_all_exp         new_models_CNN_32_all_Exp
# 23          23          cnn_32_all_relu        new_models_CNN_32_all_ReLU
# 24          24  basenji_v2_binloss_relu     basenji_v2_binloss_basenji_v2
# 25          25                    bpnet             bpnet_augmentation_48
#
#         A549    HCT116   GM12878      K562      PC-3     HepG2
# 0   0.631905  0.634136  0.556909  0.610139  0.498113  0.612955
# 1   0.644551  0.623511  0.540928  0.592135  0.492168  0.586155
# 2   0.648810  0.622500  0.521219  0.605254  0.505533  0.598627
# 3   0.631002  0.620310  0.514730  0.598176  0.500083  0.569723
# 4   0.639870  0.645721  0.606411  0.606989  0.578999  0.635519
# 5   0.638054  0.651104  0.606609  0.612077  0.578736  0.645325
# 6   0.592449  0.592355  0.496773  0.514070  0.450311  0.550426
# 7   0.641775  0.643460  0.580139  0.607368  0.552579  0.621994
# 8   0.754242  0.719093  0.669570  0.687969  0.584345  0.673214
# 9   0.735452  0.704582  0.645654  0.683041  0.538408  0.667204
# 10  0.757970  0.719471  0.667432  0.686772  0.600329  0.679293
# 11  0.745465  0.713624  0.652030  0.683239  0.561896  0.669989
# 12  0.749078  0.721714  0.685792  0.689395  0.617952  0.729218
# 13  0.738883  0.710612  0.661004  0.691644  0.586359  0.715892
# 14  0.732858  0.704847  0.662590  0.673304  0.589967  0.704706
# 15  0.720982  0.695657  0.644368  0.672157  0.562369  0.688994
# 16  0.717903  0.673234  0.598886  0.671332  0.489284  0.655765
# 17  0.731765  0.694181  0.613117  0.673166  0.529403  0.658106
# 18  0.728898  0.685016  0.604632  0.669928  0.494843  0.658521
# 19  0.730026  0.682136  0.584849  0.667611  0.508629  0.652250
# 20  0.720688  0.676133  0.598934  0.669961  0.489532  0.656299
# 21  0.726958  0.683580  0.589879  0.673263  0.513438  0.656201
# 22  0.721079  0.672452  0.596403  0.668972  0.494632  0.656075
# 23  0.728933  0.685992  0.595297  0.668940  0.515846  0.654260
# 24  0.740202  0.699162  0.652223  0.681122  0.579475  0.711553
# 25  0.737374  0.710005  0.640610  0.675683  0.556392  0.667583
